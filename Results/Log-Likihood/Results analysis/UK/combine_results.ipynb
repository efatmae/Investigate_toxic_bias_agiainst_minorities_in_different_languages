# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ALBERT_results_femm_sos = pd.read_csv("ALBERT/AlBERT_results_Femm_SOS.csv")
ALBERT_results_masc_sos = pd.read_csv("ALBERT/AlBERT_results_Masc_SOS.csv")
ALBERT_results_NB_sos = pd.read_csv("ALBERT/AlBERT_results_NB_SOS.csv")

BART_results_femm_sos = pd.read_csv("BART/BART_results_Femm_SOS.csv")
BART_results_masc_sos = pd.read_csv("BART/BART_results_Masc_SOS.csv")
BART_results_NB_sos = pd.read_csv("BART/BART_results_NB_SOS.csv")

BERT_results_femm_sos = pd.read_csv("BERT/BERT_results_Femm_SOS.csv")
BERT_results_masc_sos = pd.read_csv("BERT/BERT_results_Masc_SOS.csv")
BERT_results_NB_sos = pd.read_csv("BERT/BERT_results_NB_SOS.csv")

XLM_Roberta_results_femm_sos = pd.read_csv(
    "XLM_Roberta/XML_Roberta_results_Femm.csv")
XLM_Roberta_results_masc_sos = pd.read_csv(
    "XLM_Roberta/XML_Roberta_results_Masc.csv")
XLM_Roberta_results_NB_sos = pd.read_csv(
    "XLM_Roberta/XML_Roberta_results_NB.csv")

# %%
combine_results = pd.concat([ALBERT_results_femm_sos,
                             ALBERT_results_masc_sos,
                             ALBERT_results_NB_sos,
                             
                             BART_results_femm_sos,
                             BART_results_masc_sos,
                             BART_results_NB_sos,
                             
                             BERT_results_femm_sos,
                             BERT_results_masc_sos,
                             BERT_results_NB_sos,
                             
                             XLM_Roberta_results_femm_sos,
                             XLM_Roberta_results_masc_sos,
                             XLM_Roberta_results_NB_sos
    
])

# %%
combine_results["Marginalized_Bias_Score"] = combine_results["Marginalized_Bias_Score"].round(3)
combine_results["Non_Maarginalized_Bias_scores"] = combine_results["Non_Maarginalized_Bias_scores"].round(3)

# %%
combine_results.to_csv("UK_Combined_MLM_results.csv", index=False)

# %%
combine_results["Mar_mins_Non_Mar"] = combine_results["Marginalized_Bias_Score"] - combine_results["Non_Maarginalized_Bias_scores"]

# %%
len(combine_results[combine_results["Mar_mins_Non_Mar"]>0]),len(combine_results[combine_results["Mar_mins_Non_Mar"]<0])
# Out:
# (20, 38)

# %%
SOS_high_aginst_marginalised = combine_results[combine_results["Marginalized_Bias_Score"] > combine_results["Non_Maarginalized_Bias_scores"]]

# %%
SOS_high_aginst_marginalised.to_csv("SOS_high_aginst_marginalised.csv", index=False)

# %%
SOS_high_aginst_non_marginalised = combine_results[combine_results["Marginalized_Bias_Score"] < combine_results["Non_Maarginalized_Bias_scores"]]

# %%
SOS_high_aginst_non_marginalised.to_csv("SOS_high_aginst_non_marginalised.csv", index=False)

# %%
len(combine_results)
# Out:
# 60

# %%
len(SOS_high_aginst_marginalised)
# Out:
# 20

# %%
len(SOS_high_aginst_non_marginalised)
# Out:
# 38

# %%
combine_results[combine_results["Marginalized_Bias_Score"] > 0.5]
# Out:
#                  Model_Name           Bias_Type  Marginalized_Bias_Score  \
# 2       AlBERT_results_Femm                Race                    0.544
# 3       AlBERT_results_Femm            Religion                    0.627
# 3       AlBERT_results_Masc            Religion                    0.568
# 0           BART_results_NB  Sexual_orientation                    0.502
# 2           BART_results_NB                Race                    0.508
# 4           BART_results_NB    Physical_ability                    0.506
# 0         BERT_results_Femm  Sexual_orientation                    0.634
# 1         BERT_results_Femm              Gender                    0.611
# 2         BERT_results_Femm                Race                    0.663
# 3         BERT_results_Femm            Religion                    0.627
# 4         BERT_results_Femm    Physical_ability                    0.636
# 0         BERT_results_Masc  Sexual_orientation                    0.649
# 1         BERT_results_Masc              Gender                    0.632
# 2         BERT_results_Masc                Race                    0.690
# 3         BERT_results_Masc            Religion                    0.643
# 4         BERT_results_Masc    Physical_ability                    0.654
# 0           BERT_results_NB  Sexual_orientation                    0.673
# 1           BERT_results_NB              Gender                    0.669
# 2           BERT_results_NB                Race                    0.660
# 3           BERT_results_NB            Religion                    0.632
# 4           BERT_results_NB    Physical_ability                    0.661
# 0  XML_Roberta_results_Femm  Sexual_orientation                    0.544
# 2  XML_Roberta_results_Femm                Race                    0.565
# 3  XML_Roberta_results_Femm            Religion                    0.514
# 4  XML_Roberta_results_Femm    Physical_ability                    0.504
# 0  XML_Roberta_results_Masc  Sexual_orientation                    0.502
# 2  XML_Roberta_results_Masc                Race                    0.521
# 3  XML_Roberta_results_Masc            Religion                    0.535
# 3    XML_Roberta_results_NB            Religion                    0.541
#
#    Non_Maarginalized_Bias_scores  Mar_mins_Non_Mar
# 2                          0.561            -0.017
# 3                          0.600             0.027
# 3                          0.524             0.044
# 0                          0.514            -0.012
# 2                          0.595            -0.087
# 4                          0.486             0.020
# 0                          0.649            -0.015
# 1                          0.649            -0.038
# 2                          0.662             0.001
# 3                          0.649            -0.022
# 4                          0.703            -0.067
# 0                          0.669            -0.020
# 1                          0.631             0.001
# 2                          0.662             0.028
# 3                          0.703            -0.060
# 4                          0.757            -0.103
# 0                          0.696            -0.023
# 1                          0.676            -0.007
# 2                          0.635             0.025
# 3                          0.622             0.010
# 4                          0.757            -0.096
# 0                          0.574            -0.030
# 2                          0.608            -0.043
# 3                          0.541            -0.027
# 4                          0.486             0.018
# 0                          0.514            -0.012
# 2                          0.588            -0.067
# 3                          0.546            -0.011
# 3                          0.546            -0.005

# %%
combine_results[combine_results["Non_Maarginalized_Bias_scores"] > 0.5]
# Out:
#                  Model_Name           Bias_Type  Marginalized_Bias_Score  \
# 2       AlBERT_results_Femm                Race                    0.544
# 3       AlBERT_results_Femm            Religion                    0.627
# 3       AlBERT_results_Masc            Religion                    0.568
# 0           BART_results_NB  Sexual_orientation                    0.502
# 2           BART_results_NB                Race                    0.508
# 3           BART_results_NB            Religion                    0.465
# 0         BERT_results_Femm  Sexual_orientation                    0.634
# 1         BERT_results_Femm              Gender                    0.611
# 2         BERT_results_Femm                Race                    0.663
# 3         BERT_results_Femm            Religion                    0.627
# 4         BERT_results_Femm    Physical_ability                    0.636
# 0         BERT_results_Masc  Sexual_orientation                    0.649
# 1         BERT_results_Masc              Gender                    0.632
# 2         BERT_results_Masc                Race                    0.690
# 3         BERT_results_Masc            Religion                    0.643
# 4         BERT_results_Masc    Physical_ability                    0.654
# 0           BERT_results_NB  Sexual_orientation                    0.673
# 1           BERT_results_NB              Gender                    0.669
# 2           BERT_results_NB                Race                    0.660
# 3           BERT_results_NB            Religion                    0.632
# 4           BERT_results_NB    Physical_ability                    0.661
# 0  XML_Roberta_results_Femm  Sexual_orientation                    0.544
# 1  XML_Roberta_results_Femm              Gender                    0.480
# 2  XML_Roberta_results_Femm                Race                    0.565
# 3  XML_Roberta_results_Femm            Religion                    0.514
# 0  XML_Roberta_results_Masc  Sexual_orientation                    0.502
# 1  XML_Roberta_results_Masc              Gender                    0.463
# 2  XML_Roberta_results_Masc                Race                    0.521
# 3  XML_Roberta_results_Masc            Religion                    0.535
# 4  XML_Roberta_results_Masc    Physical_ability                    0.457
# 1    XML_Roberta_results_NB              Gender                    0.446
# 2    XML_Roberta_results_NB                Race                    0.499
# 3    XML_Roberta_results_NB            Religion                    0.541
# 4    XML_Roberta_results_NB    Physical_ability                    0.472
#
#    Non_Maarginalized_Bias_scores  Mar_mins_Non_Mar
# 2                          0.561            -0.017
# 3                          0.600             0.027
# 3                          0.524             0.044
# 0                          0.514            -0.012
# 2                          0.595            -0.087
# 3                          0.600            -0.135
# 0                          0.649            -0.015
# 1                          0.649            -0.038
# 2                          0.662             0.001
# 3                          0.649            -0.022
# 4                          0.703            -0.067
# 0                          0.669            -0.020
# 1                          0.631             0.001
# 2                          0.662             0.028
# 3                          0.703            -0.060
# 4                          0.757            -0.103
# 0                          0.696            -0.023
# 1                          0.676            -0.007
# 2                          0.635             0.025
# 3                          0.622             0.010
# 4                          0.757            -0.096
# 0                          0.574            -0.030
# 1                          0.523            -0.043
# 2                          0.608            -0.043
# 3                          0.541            -0.027
# 0                          0.514            -0.012
# 1                          0.559            -0.096
# 2                          0.588            -0.067
# 3                          0.546            -0.011
# 4                          0.649            -0.192
# 1                          0.523            -0.077
# 2                          0.601            -0.102
# 3                          0.546            -0.005
# 4                          0.568            -0.096

# %%
Femm_data = combine_results[combine_results["Model_Name"].str.contains("_Femm")]

# %%
Masc_data = combine_results[combine_results["Model_Name"].str.contains("_Masc")]

# %%
NB_data = combine_results[combine_results["Model_Name"].str.contains("_NB")]

# %%
fig, axs = plt.subplots(2,3, figsize=(15, 6))
fig.suptitle("SOS MLM Bias scores English MLM (UK)", fontweight="bold")

modelnames = ["ALBERT", "BART", "BERT", "XLM_Roberta_Multilingual"]

marginalized_femm = Femm_data.pivot(index='Model_Name', columns="Bias_Type", values="Marginalized_Bias_Score")
sns.heatmap(marginalized_femm, annot=True,  vmin=0.5, vmax=0.8, ax = axs[0,0], xticklabels=False, yticklabels=True)
axs[0,0].set_title("Femm-Marginalized", fontweight="bold")
axs[0,0].set_yticks(range(0,4), modelnames)
axs[0,0].set(xlabel="")
axs[0,0].set(ylabel="")

marginalized_masc = Masc_data.pivot(index='Model_Name', columns="Bias_Type", values="Marginalized_Bias_Score")
sns.heatmap(marginalized_masc, annot=True,  vmin=0.5, vmax=0.8, ax =axs[0,1], xticklabels=False, yticklabels=False)
axs[0,1].set(xlabel="")
axs[0,1].set_title("Masc-Marginalized", fontweight="bold")

marginalized_NB = NB_data.pivot(index='Model_Name', columns="Bias_Type", values="Marginalized_Bias_Score")
sns.heatmap(marginalized_NB, annot=True,  vmin=0.5, vmax=0.8, ax=axs[0,2], xticklabels=False, yticklabels=False)
axs[0,2].set(xlabel="")
axs[0,2].set_title("NB-Marginalized", fontweight="bold")

marginalized_femm = Femm_data.pivot(index='Model_Name', columns="Bias_Type", values="Non_Maarginalized_Bias_scores")
sns.heatmap(marginalized_femm, annot=True,  vmin=0.5, vmax=0.8, ax = axs[1,0])
axs[1,0].set_yticks(range(0,4), modelnames)
axs[1,0].set_title("Femm-Dominant", fontweight="bold")
axs[1,0].set(xlabel="")

marginalized_masc = Masc_data.pivot(index='Model_Name', columns="Bias_Type", values="Non_Maarginalized_Bias_scores")
sns.heatmap(marginalized_masc, annot=True,  vmin=0.5, vmax=0.8, ax =axs[1,1], xticklabels=True, yticklabels=False)
axs[1,1].set_title("Masc-Dominant", fontweight="bold")

marginalized_NB = NB_data.pivot(index='Model_Name', columns="Bias_Type", values="Non_Maarginalized_Bias_scores")
sns.heatmap(marginalized_NB, annot=True,  vmin=0.5, vmax=0.8, ax=axs[1,2], xticklabels=True, yticklabels=False)
axs[1,2].set(xlabel="")
axs[1,2].set_title("NB-Dominant", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'NB-Dominant')

# %%
plt.savefig("SOS MLM Bias scores English MLM (UK).pdf", bbox_inches="tight", dpi='figure', format="pdf")

# %%
combine_results["Mar_mins_Non_Mar"] = combine_results["Marginalized_Bias_Score"] - combine_results["Non_Maarginalized_Bias_scores"]
fig, axs = plt.subplots(1,3, figsize=(15, 3))
fig.suptitle("SOS MLM Bias scores English MLM (UK)", fontweight="bold")

modelnames = ["ALBERT", "BART", "BERT", "XLM_Roberta_Multilingual"]

marginalized_femm = Femm_data.pivot(index='Model_Name', columns="Bias_Type", values="Mar_mins_Non_Mar")
sns.heatmap(marginalized_femm, annot=True, ax = axs[0], xticklabels=True, yticklabels=True)
axs[0].set_title("Femm", fontweight="bold")
axs[0].set_yticks(range(0,4), modelnames)
axs[0].set(xlabel="")
axs[0].set(ylabel="")

marginalized_masc = Masc_data.pivot(index='Model_Name', columns="Bias_Type", values="Mar_mins_Non_Mar")
sns.heatmap(marginalized_masc, annot=True,  ax =axs[1], xticklabels=True, yticklabels=False)
axs[1].set(xlabel="")
axs[1].set_title("Masc", fontweight="bold")

marginalized_NB = NB_data.pivot(index='Model_Name', columns="Bias_Type", values="Mar_mins_Non_Mar")
sns.heatmap(marginalized_NB, annot=True, ax=axs[2], xticklabels=True, yticklabels=False)
axs[2].set(xlabel="")
axs[2].set_title("NB", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'NB')
