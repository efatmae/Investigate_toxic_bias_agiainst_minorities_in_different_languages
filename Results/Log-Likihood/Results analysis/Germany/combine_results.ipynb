# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
germnBert_results_femm_sos = pd.read_csv("German_BERT/BERT_results_Femm_SOS.csv")
germnBert_results_masc_sos = pd.read_csv("German_BERT/BERT_results_Masc_SOS.csv")
germnBert_results_NB_sos = pd.read_csv("German_BERT/BERT_results_NB_SOS.csv")

germanBart_results_femm_sos = pd.read_csv("German_BART/BART_results_Femm_SOS.csv")
germanBart_results_masc_sos = pd.read_csv("German_BART/BART_results_Masc_SOS.csv")
germanBart_results_NB_sos = pd.read_csv("German_BART/BART_results_NB_SOS.csv")

XLM_RoBERTa_German_results_femm_sos = pd.read_csv("XLM_RoBERTa_German/XLM_RoBERTa_German_results_Femm_SOS.csv")
XLM_RoBERTa_German_results_masc_sos = pd.read_csv("XLM_RoBERTa_German/XLM_RoBERTa_German_results_Masc_SOS.csv")
XLM_RoBERTa_German_results_NB_sos = pd.read_csv("XLM_RoBERTa_German/XLM_RoBERTa_German_results_NB_SOS.csv")

XLM_Roberta_Multilingual_results_femm_sos = pd.read_csv(
    "XLM_Roberta_Multilingual/XML_Roberta_results_Femm.csv")
XLM_Roberta_Multilingual_results_masc_sos = pd.read_csv(
    "XLM_Roberta_Multilingual/XML_Roberta_results_Masc.csv")
XLM_Roberta_Multilingual_results_NB_sos = pd.read_csv(
    "XLM_Roberta_Multilingual/XML_Roberta_results_NB.csv")

# %%
combine_results = pd.concat([germnBert_results_femm_sos,
                             germnBert_results_masc_sos,
                             germnBert_results_NB_sos,
                             
                             germanBart_results_femm_sos,
                             germanBart_results_masc_sos,
                             germanBart_results_NB_sos,
                             
                             XLM_RoBERTa_German_results_femm_sos,
                             XLM_RoBERTa_German_results_masc_sos,
                             XLM_RoBERTa_German_results_NB_sos,
                             
                             XLM_Roberta_Multilingual_results_femm_sos,
                             XLM_Roberta_Multilingual_results_masc_sos,
                             XLM_Roberta_Multilingual_results_NB_sos
    
])

# %%
combine_results["Marginalized_Bias_Score"] = combine_results["Marginalized_Bias_Score"].round(3)
combine_results["Non_Maarginalized_Bias_scores"] = combine_results["Non_Maarginalized_Bias_scores"].round(3)

# %%
combine_results.to_csv("German_Combined_MLM_results.csv", index=False)

# %%
combine_results["Mar_mins_Non_Mar"] = combine_results["Marginalized_Bias_Score"] - combine_results["Non_Maarginalized_Bias_scores"]

# %%
combine_results["Mar_mins_Non_Mar"] = combine_results["Marginalized_Bias_Score"] - combine_results["Non_Maarginalized_Bias_scores"]
combine_results["Mar_mins_Non_Mar"].hist()
# Out:
# <Axes: >

# %%
len(combine_results[combine_results["Mar_mins_Non_Mar"]>0]),len(combine_results[combine_results["Mar_mins_Non_Mar"]<0])
# Out:
# (39, 31)

# %%
SOS_high_aginst_marginalised = combine_results[combine_results["Marginalized_Bias_Score"] > combine_results["Non_Maarginalized_Bias_scores"]]

# %%
SOS_high_aginst_marginalised.to_csv("SOS_high_aginst_marginalised.csv", index=False)

# %%
SOS_high_aginst_non_marginalised = combine_results[combine_results["Marginalized_Bias_Score"] < combine_results["Non_Maarginalized_Bias_scores"]]

# %%
SOS_high_aginst_non_marginalised.to_csv("SOS_high_aginst_non_marginalised.csv", index=False)

# %%
len(combine_results)
# Out:
# 72

# %%
len(SOS_high_aginst_marginalised)
# Out:
# 39

# %%
len(SOS_high_aginst_non_marginalised)
# Out:
# 31

# %%
combine_results[combine_results["Marginalized_Bias_Score"] > 0.5]
# Out:
#                       Model_Name           Bias_Type  Marginalized_Bias_Score  \
# 0              BERT_results_Femm  Sexual_orientation                    0.622
# 1              BERT_results_Femm              Gender                    0.583
# 2              BERT_results_Femm            Refugees                    0.654
# 3              BERT_results_Femm                Race                    0.653
# 4              BERT_results_Femm            Religion                    0.598
# 5              BERT_results_Femm    Physical_ability                    0.522
# 0              BERT_results_Masc  Sexual_orientation                    0.627
# 1              BERT_results_Masc              Gender                    0.640
# 2              BERT_results_Masc            Refugees                    0.681
# 3              BERT_results_Masc                Race                    0.703
# 4              BERT_results_Masc            Religion                    0.661
# 5              BERT_results_Masc    Physical_ability                    0.532
# 0                BERT_results_NB  Sexual_orientation                    0.676
# 1                BERT_results_NB              Gender                    0.679
# 2                BERT_results_NB            Refugees                    0.708
# 3                BERT_results_NB                Race                    0.714
# 4                BERT_results_NB            Religion                    0.667
# 5                BERT_results_NB    Physical_ability                    0.584
# 0              BART_results_Femm  Sexual_orientation                    0.532
# 1              BART_results_Femm              Gender                    0.568
# 3              BART_results_Femm                Race                    0.541
# 4              BART_results_Femm            Religion                    0.550
# 5              BART_results_Femm    Physical_ability                    0.535
# 0              BART_results_Masc  Sexual_orientation                    0.557
# 1              BART_results_Masc              Gender                    0.577
# 2              BART_results_Masc            Refugees                    0.541
# 3              BART_results_Masc                Race                    0.533
# 4              BART_results_Masc            Religion                    0.565
# 5              BART_results_Masc    Physical_ability                    0.551
# 0                BART_results_NB  Sexual_orientation                    0.541
# 1                BART_results_NB              Gender                    0.571
# 2                BART_results_NB            Refugees                    0.541
# 3                BART_results_NB                Race                    0.552
# 4                BART_results_NB            Religion                    0.559
# 5                BART_results_NB    Physical_ability                    0.584
# 0  XLM_RoBERTa_German_results_NB  Sexual_orientation                    0.535
# 2  XLM_RoBERTa_German_results_NB            Refugees                    0.541
# 3  XLM_RoBERTa_German_results_NB                Race                    0.517
# 4  XLM_RoBERTa_German_results_NB            Religion                    0.514
# 0       XML_Roberta_results_Femm  Sexual_orientation                    0.595
# 1       XML_Roberta_results_Femm              Gender                    0.511
# 2       XML_Roberta_results_Femm            Refugees                    0.578
# 3       XML_Roberta_results_Femm                Race                    0.622
# 4       XML_Roberta_results_Femm            Religion                    0.538
# 5       XML_Roberta_results_Femm    Physical_ability                    0.595
# 0       XML_Roberta_results_Masc  Sexual_orientation                    0.530
# 1       XML_Roberta_results_Masc              Gender                    0.511
# 2       XML_Roberta_results_Masc            Refugees                    0.551
# 3       XML_Roberta_results_Masc                Race                    0.606
# 4       XML_Roberta_results_Masc            Religion                    0.520
# 5       XML_Roberta_results_Masc    Physical_ability                    0.541
# 0         XML_Roberta_results_NB  Sexual_orientation                    0.503
# 5         XML_Roberta_results_NB    Physical_ability                    0.541
#
#    Non_Maarginalized_Bias_scores  Mar_mins_Non_Mar
# 0                          0.568             0.054
# 1                          0.622            -0.039
# 2                          0.595             0.059
# 3                          0.649             0.004
# 4                          0.568             0.030
# 5                          0.527            -0.005
# 0                          0.676            -0.049
# 1                          0.689            -0.049
# 2                          0.676             0.005
# 3                          0.676             0.027
# 4                          0.649             0.012
# 5                          0.554            -0.022
# 0                          0.622             0.054
# 1                          0.649             0.030
# 2                          0.649             0.059
# 3                          0.689             0.025
# 4                          0.696            -0.029
# 5                          0.635            -0.051
# 0                          0.514             0.018
# 1                          0.568             0.000
# 3                          0.514             0.027
# 4                          0.507             0.043
# 5                          0.500             0.035
# 0                          0.514             0.043
# 1                          0.568             0.009
# 2                          0.405             0.136
# 3                          0.500             0.033
# 4                          0.547             0.018
# 5                          0.581            -0.030
# 0                          0.459             0.082
# 1                          0.608            -0.037
# 2                          0.432             0.109
# 3                          0.581            -0.029
# 4                          0.534             0.025
# 5                          0.595            -0.011
# 0                          0.459             0.076
# 2                          0.486             0.055
# 3                          0.527            -0.010
# 4                          0.426             0.088
# 0                          0.459             0.136
# 1                          0.595            -0.084
# 2                          0.541             0.037
# 3                          0.716            -0.094
# 4                          0.642            -0.104
# 5                          0.500             0.095
# 0                          0.486             0.044
# 1                          0.676            -0.165
# 2                          0.676            -0.125
# 3                          0.622            -0.016
# 4                          0.615            -0.095
# 5                          0.608            -0.067
# 0                          0.432             0.071
# 5                          0.514             0.027

# %%
combine_results[combine_results["Non_Maarginalized_Bias_scores"] > 0.5]
# Out:
#                       Model_Name           Bias_Type  Marginalized_Bias_Score  \
# 0              BERT_results_Femm  Sexual_orientation                    0.622
# 1              BERT_results_Femm              Gender                    0.583
# 2              BERT_results_Femm            Refugees                    0.654
# 3              BERT_results_Femm                Race                    0.653
# 4              BERT_results_Femm            Religion                    0.598
# 5              BERT_results_Femm    Physical_ability                    0.522
# 0              BERT_results_Masc  Sexual_orientation                    0.627
# 1              BERT_results_Masc              Gender                    0.640
# 2              BERT_results_Masc            Refugees                    0.681
# 3              BERT_results_Masc                Race                    0.703
# 4              BERT_results_Masc            Religion                    0.661
# 5              BERT_results_Masc    Physical_ability                    0.532
# 0                BERT_results_NB  Sexual_orientation                    0.676
# 1                BERT_results_NB              Gender                    0.679
# 2                BERT_results_NB            Refugees                    0.708
# 3                BERT_results_NB                Race                    0.714
# 4                BERT_results_NB            Religion                    0.667
# 5                BERT_results_NB    Physical_ability                    0.584
# 0              BART_results_Femm  Sexual_orientation                    0.532
# 1              BART_results_Femm              Gender                    0.568
# 2              BART_results_Femm            Refugees                    0.476
# 3              BART_results_Femm                Race                    0.541
# 4              BART_results_Femm            Religion                    0.550
# 0              BART_results_Masc  Sexual_orientation                    0.557
# 1              BART_results_Masc              Gender                    0.577
# 4              BART_results_Masc            Religion                    0.565
# 5              BART_results_Masc    Physical_ability                    0.551
# 1                BART_results_NB              Gender                    0.571
# 3                BART_results_NB                Race                    0.552
# 4                BART_results_NB            Religion                    0.559
# 5                BART_results_NB    Physical_ability                    0.584
# 1  XLM_RoBERTa_German_results_NB              Gender                    0.471
# 3  XLM_RoBERTa_German_results_NB                Race                    0.517
# 1       XML_Roberta_results_Femm              Gender                    0.511
# 2       XML_Roberta_results_Femm            Refugees                    0.578
# 3       XML_Roberta_results_Femm                Race                    0.622
# 4       XML_Roberta_results_Femm            Religion                    0.538
# 1       XML_Roberta_results_Masc              Gender                    0.511
# 2       XML_Roberta_results_Masc            Refugees                    0.551
# 3       XML_Roberta_results_Masc                Race                    0.606
# 4       XML_Roberta_results_Masc            Religion                    0.520
# 5       XML_Roberta_results_Masc    Physical_ability                    0.541
# 2         XML_Roberta_results_NB            Refugees                    0.486
# 3         XML_Roberta_results_NB                Race                    0.494
# 5         XML_Roberta_results_NB    Physical_ability                    0.541
#
#    Non_Maarginalized_Bias_scores  Mar_mins_Non_Mar
# 0                          0.568             0.054
# 1                          0.622            -0.039
# 2                          0.595             0.059
# 3                          0.649             0.004
# 4                          0.568             0.030
# 5                          0.527            -0.005
# 0                          0.676            -0.049
# 1                          0.689            -0.049
# 2                          0.676             0.005
# 3                          0.676             0.027
# 4                          0.649             0.012
# 5                          0.554            -0.022
# 0                          0.622             0.054
# 1                          0.649             0.030
# 2                          0.649             0.059
# 3                          0.689             0.025
# 4                          0.696            -0.029
# 5                          0.635            -0.051
# 0                          0.514             0.018
# 1                          0.568             0.000
# 2                          0.649            -0.173
# 3                          0.514             0.027
# 4                          0.507             0.043
# 0                          0.514             0.043
# 1                          0.568             0.009
# 4                          0.547             0.018
# 5                          0.581            -0.030
# 1                          0.608            -0.037
# 3                          0.581            -0.029
# 4                          0.534             0.025
# 5                          0.595            -0.011
# 1                          0.568            -0.097
# 3                          0.527            -0.010
# 1                          0.595            -0.084
# 2                          0.541             0.037
# 3                          0.716            -0.094
# 4                          0.642            -0.104
# 1                          0.676            -0.165
# 2                          0.676            -0.125
# 3                          0.622            -0.016
# 4                          0.615            -0.095
# 5                          0.608            -0.067
# 2                          0.568            -0.082
# 3                          0.568            -0.074
# 5                          0.514             0.027

# %%
Femm_data = combine_results[combine_results["Model_Name"].str.contains("_Femm")]

# %%
Masc_data = combine_results[combine_results["Model_Name"].str.contains("_Masc")]

# %%
NB_data = combine_results[combine_results["Model_Name"].str.contains("_NB")]

# %%
fig, axs = plt.subplots(2,3, figsize=(15, 6))
fig.suptitle("SOS MLM Bias scores (German MLMs- Germany)", fontweight="bold")

modelnames = ["German_BERT", "German_BART", "XLM_RoBERTa_German", "XLM_Roberta_Multilingual"]

marginalized_femm = Femm_data.pivot(index='Model_Name', columns="Bias_Type", values="Marginalized_Bias_Score")
sns.heatmap(marginalized_femm, annot=True,  vmin=0.5, vmax=0.8, ax = axs[0,0], xticklabels=False, yticklabels=True)
axs[0,0].set_title("Femm-Marginalized", fontweight="bold")
axs[0,0].set_yticks(range(0,4), modelnames)
axs[0,0].set(xlabel="")
axs[0,0].set(ylabel="")

marginalized_masc = Masc_data.pivot(index='Model_Name', columns="Bias_Type", values="Marginalized_Bias_Score")
sns.heatmap(marginalized_masc, annot=True,  vmin=0.5, vmax=0.8, ax =axs[0,1], xticklabels=False, yticklabels=False)
axs[0,1].set(xlabel="")
axs[0,1].set_title("Masc-Marginalized", fontweight="bold")

marginalized_NB = NB_data.pivot(index='Model_Name', columns="Bias_Type", values="Marginalized_Bias_Score")
sns.heatmap(marginalized_NB, annot=True,  vmin=0.5, vmax=0.8, ax=axs[0,2], xticklabels=False, yticklabels=False)
axs[0,2].set(xlabel="")
axs[0,2].set_title("NB-Marginalized", fontweight="bold")

marginalized_femm = Femm_data.pivot(index='Model_Name', columns="Bias_Type", values="Non_Maarginalized_Bias_scores")
sns.heatmap(marginalized_femm, annot=True,  vmin=0.5, vmax=0.8, ax = axs[1,0])
axs[1,0].set_yticks(range(0,4), modelnames)
axs[1,0].set_title("Femm-Dominant", fontweight="bold")
axs[1,0].set(xlabel="")

marginalized_masc = Masc_data.pivot(index='Model_Name', columns="Bias_Type", values="Non_Maarginalized_Bias_scores")
sns.heatmap(marginalized_masc, annot=True,  vmin=0.5, vmax=0.8, ax =axs[1,1], xticklabels=True, yticklabels=False)
axs[1,1].set_title("Masc-Dominant", fontweight="bold")

marginalized_NB = NB_data.pivot(index='Model_Name', columns="Bias_Type", values="Non_Maarginalized_Bias_scores")
sns.heatmap(marginalized_NB, annot=True,  vmin=0.5, vmax=0.8, ax=axs[1,2], xticklabels=True, yticklabels=False)
axs[1,2].set(xlabel="")
axs[1,2].set_title("NB-Dominant", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'NB-Dominant')

# %%
plt.savefig("SOS MLM Bias scores (German MLMs- Germany).pdf", bbox_inches=None, dpi='figure', format="pdf")

# %%
fig, axs = plt.subplots(1,3, figsize=(15, 3))
fig.suptitle("SOS MLM Bias scores (German MLMs- Germany)", fontweight="bold")

modelnames = ["German_BERT", "German_BART", "XLM_RoBERTa_German", "XLM_Roberta_Multilingual"]

marginalized_femm = Femm_data.pivot(index='Model_Name', columns="Bias_Type", values="Mar_mins_Non_Mar")
sns.heatmap(marginalized_femm, annot=True, ax = axs[0], xticklabels=True, yticklabels=True)
axs[0].set_title("Femm-Marginalized", fontweight="bold")
axs[0].set_yticks(range(0,4), modelnames)
axs[0].set(xlabel="")
axs[0].set(ylabel="")

marginalized_masc = Masc_data.pivot(index='Model_Name', columns="Bias_Type", values="Mar_mins_Non_Mar")
sns.heatmap(marginalized_masc, annot=True,  ax =axs[1], xticklabels=True, yticklabels=False)
axs[1].set(xlabel="")
axs[1].set_title("Masc-Marginalized", fontweight="bold")

marginalized_NB = NB_data.pivot(index='Model_Name', columns="Bias_Type", values="Mar_mins_Non_Mar")
sns.heatmap(marginalized_NB, annot=True,   ax=axs[2], xticklabels=True, yticklabels=False)
axs[2].set(xlabel="")
axs[2].set_title("NB-Marginalized", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'NB-Marginalized')
